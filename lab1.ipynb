# %% [markdown]
# <a href="https://colab.research.google.com/github/Vikram-Kumar-Sahu/Google-Collab/blob/main/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("vikram")
# Out:
# vikram

# %%
a = 5
print (a, "is of type",type(a))
# Out:
# 5 is of type <class 'int'>

# %%
a = 2.0
print (a, "is of type",type(a))
# Out:
# 2.0 is of type <class 'float'>

# %%
a = 1+2j
print (a, "is of type",type(a))
# Out:
# (1+2j) is of type <class 'complex'>

# %%
num1=123
num2=1.23
new=num1+num2
print("datatype of num1:",type(num1))
print("datatype of num2:",type(num2))
print("datatype of new:",type(new))
# Out:
# datatype of num1: <class 'int'>
# datatype of num2: <class 'float'>
# datatype of new: <class 'float'>

# %%
num1=123
num2="456"
print(num1+num2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1016376036.py in <cell line: 0>()
#       1 num1=123
#       2 num2="456"
# ----> 3 print(num1+num2)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a,b,c=5,3.2,"Hello"

# %%
print(a)
print(b)
print(c)
# Out:
# 5
# 3.2
# Hello

# %%
S = "Michael Jackson "
print(S*3)
# Out:
# Michael Jackson Michael Jackson Michael Jackson

# %%
print("Michael \\ Jackson")
# Out:
# Michael \ Jackson

# %%
print("Michael \ Jackson")
# Out:
# Michael \ Jackson
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# /tmp/ipython-input-4241414709.py:1: SyntaxWarning: invalid escape sequence '\ '
#   print("Michael \ Jackson")

# %%
A="THis is a string"
A.find("is")
# Out:
# 2

# %%
tuple1=('disco',12,4.5)
tupel2=tuple1+("hard rock",10)
print (tupel2)
# Out:
# ('disco', 12, 4.5, 'hard rock', 10)

# %%
print(tupel2[0:3])
# Out:
# ('disco', 12, 4.5)

# %%
len(tupel2)
# Out:
# 5

# %%
a="Vikram Kumar Sahu"
print(a.split())
# Out:
# ['Vikram', 'Kumar', 'Sahu']

# %%
A=["hard rock",10,4.5]
B=A
A[0]="banana"
print("list A: ",A,"\nlist B: ",B)
# Out:
# list A:  ['banana', 10, 4.5]
# list B:  ['banana', 10, 4.5]

# %%
C={'Thriller','Back in Black','AC/DC'}
D={'Dark side of Moon','Back in Black','AC?DC',1982}
E=C&D
print (E)
# Out:
# {'Back in Black'}

# %%
E=C.union(D)
print(E)
# Out:
# {'Thriller', 'Back in Black', 'AC?DC', 'Dark side of Moon', 1982, 'AC/DC'}
